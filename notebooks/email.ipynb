# %%
import pandas as pd
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from jinja2 import Environment, FileSystemLoader
import time
import re
import os

# %%
# %pip install -U google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-1.67.0-py3-none-any.whl.metadata (52 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from google-genai) (4.12.1)
# Collecting google-auth<3.0.0,>=2.47.0 (from google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading google_auth-2.49.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from google-genai) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from google-genai) (9.1.4)
# Collecting websockets<17.0,>=13.0.0 (from google-genai)
#   Downloading websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading cryptography-46.0.5-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Requirement already satisfied: certifi in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/lundenmandigo/Documents/UMICH/S26/SI699/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading pyasn1-0.6.2-py3-none-any.whl.metadata (8.4 kB)
# Downloading google_genai-1.67.0-py3-none-any.whl (733 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.5/733.5 kB 12.1 MB/s  0:00:00
# Downloading google_auth-2.49.1-py3-none-any.whl (240 kB)
# Downloading websockets-16.0-cp313-cp313-macosx_11_0_arm64.whl (175 kB)
# Downloading cryptography-46.0.5-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 37.2 MB/s  0:00:00
# Using cached cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.2-py3-none-any.whl (83 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: websockets, pycparser, pyasn1, pyasn1-modules, cffi, cryptography, google-auth, google-genai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [google-genai] [google-genai]s]
# Successfully installed cffi-2.0.0 cryptography-46.0.5 google-auth-2.49.1 google-genai-1.67.0 pyasn1-0.6.2 pyasn1-modules-0.4.2 pycparser-3.0 websockets-16.0
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
